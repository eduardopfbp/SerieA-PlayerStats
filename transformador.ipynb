# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
db_temp = pd.read_csv(r'C:\Users\eduar\OneDrive\Desktop\DEV\Football\SerieA\database_temp.csv')
db = pd.read_csv(r'C:\Users\eduar\OneDrive\Desktop\DEV\Football\SerieA\database.csv')

# Criando Backup
db.to_csv(r'C:\Users\eduar\OneDrive\Desktop\DEV\Football\SerieA\database_bu.csv', index= False)

db_temp.columns = db.columns

# Concatenando bases
db_final = pd.concat([db,db_temp], ignore_index= True)

# Tratamento de duplicadas
db_final = db_final.drop_duplicates(subset=['Player','Date'])

# %%
db_final
# Out:
#                     Player     Team   # Nation Position     Age  Minutes  \
# 0                  Vitinha    Genoa   9    POR       FW  24-155       90
# 1           Junior Messias    Genoa  10    BRA    FW,RW  33-096       90
# 2          Morten Frendrup    Genoa  32    DEN       CM  23-132       90
# 3             Milan Badelj    Genoa  47    CRO       CM  35-174       85
# 4             Jeff Ekhator    Genoa  21    ITA       LW  17-280        5
# ...                    ...      ...  ..    ...      ...     ...      ...
# 3973          Juan Miranda  Bologna  33    ESP       LB  24-310       90
# 3974           Jhon Lucumí  Bologna  26    COL       CB  26-151       90
# 3975           Sam Beukema  Bologna  31    NED       CB  26-007       90
# 3976  Lorenzo De Silvestri  Bologna  29    ITA    RB,CB  36-185       90
# 3977     Federico Ravaglia  Bologna  34    ITA       GK  25-013       90
#
#       Goals  Assists  Penalty Shoot on Goal  Penalty Shoot  Total Shoot  \
# ...

# %%
db_final.to_csv(r'C:\Users\eduar\OneDrive\Desktop\DEV\Football\SerieA\database.csv',index = False)
