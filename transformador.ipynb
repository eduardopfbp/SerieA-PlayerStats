# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
db_temp = pd.read_csv('C://Users//eduar//Desktop//DEV//Football//SerieA//database_temp.csv')
db = pd.read_csv('C://Users//eduar//Desktop//DEV//Football//SerieA//database.csv')

# Criando Backup
db.to_csv('C://Users//eduar//Desktop//DEV//Football//SerieA//database_bu.csv', index= False)

# Concatenando bases
db_final = pd.concat([db,db_temp], ignore_index= True)

# Tratamento de duplicadas
db_final = db_final.drop_duplicates(subset=['Jogador','Data'])

# %%
db_final
# Out:
#                  Jogador      Time   # Nação   Pos.   Idade  Min.  Gols  \
# 0                Vitinha     Genoa   9   POR     FW  24-155    90     0
# 1         Junior Messias     Genoa  10   BRA  FW,RW  33-096    90     1
# 2        Morten Frendrup     Genoa  32   DEN     CM  23-132    90     0
# 3           Milan Badelj     Genoa  47   CRO     CM  35-174    85     0
# 4           Jeff Ekhator     Genoa  21   ITA     LW  17-280     5     0
# ...                  ...       ...  ..   ...    ...     ...   ...   ...
# 1871  Sebastiano Luperto  Cagliari   6   ITA     CB  28-024    90     0
# 1872          Yerry Mina  Cagliari  26   COL     CB  30-007    72     0
# 1873  José Luis Palomino  Cagliari  24   ARG     CB  34-269    18     0
# 1874      Gabriele Zappa  Cagliari  28   ITA     CB  24-283    90     0
# 1875      Simone Scuffet  Cagliari  22   ITA     GK  28-122    90     0
#
#       Assis.  PB  PT  TC  CaG  CrtsA  CrtV  Contatos  Div  Crts  Bloqueios  \
# ...
